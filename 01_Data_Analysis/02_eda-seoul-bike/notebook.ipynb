# %% [markdown]
# # 서울 공공자전거 수요 패턴 분석\n\n재현 가능한 데이터 다운로드·정제·그래프 생성은 `src/` 스크립트가 담당합니다. 이 노트북은 결과를 탐색하고 추가 가설을 검증하는 공간입니다.

# %%
from pathlib import Path\nimport pandas as pd\n\nPROJECT_ROOT = Path.cwd()\nif not (PROJECT_ROOT / 'data').exists():\n    PROJECT_ROOT = PROJECT_ROOT / '01_Data_Analysis' / '02_eda-seoul-bike'\n\nbike = pd.read_csv(PROJECT_ROOT / 'data' / 'processed' / 'seoul_bike_cleaned.csv')\nbike.head()
